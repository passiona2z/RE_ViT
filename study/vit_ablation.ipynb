# %%
# ViT with adding positional embedding
# Model is saved on model_with_positional_embedding.pth
# !python vit.py --pretrained 1 --drop_rate 0.1 --weight_decay 2e-4
# Out:
# ^C

# %%
# !python vit.py --pretrained 1 --mode test
# Out:
# Namespace(batch_size=128, dataname='cifar10', drop_rate=0.1, epochs=501, img_size=32, latent_vec_dim=128, lr=0.002, mode='test', num_classes=10, num_heads=8, num_layers=12, patch_size=4, pretrained=1, save_acc=50, weight_decay=0)
# ...
# 170499072it [00:03, 47095510.84it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# test loss: 0.501, test acc 84.64 %

# %%
# !python vit.py --pretrained 0 --drop_rate 0.1 --weight_decay 2e-4
# Out:
# ^C

# %%
# ViT without adding positional embedding
# Model is saved on model_without_positional_embedding.pth
# !python vit.py --pretrained 0 --drop_rate 0.1 --weight_decay 2e-4
# Out:
# Namespace(batch_size=128, dataname='cifar10', drop_rate=0.1, epochs=501, img_size=32, latent_vec_dim=128, lr=0.002, mode='train', num_classes=10, num_heads=8, num_layers=12, patch_size=4, pretrained=0, save_acc=50, weight_decay=0.0002)
# Files already downloaded and verified
# Files already downloaded and verified
# [0] train loss: 1.788, validation loss: 1.692, validation acc 38.14 %
# [1] train loss: 1.534, validation loss: 1.528, validation acc 44.80 %
# [2] train loss: 1.433, validation loss: 1.424, validation acc 48.10 %
# [3] train loss: 1.378, validation loss: 1.357, validation acc 51.74 %
# [4] train loss: 1.340, validation loss: 1.315, validation acc 53.34 %
# [5] train loss: 1.310, validation loss: 1.314, validation acc 52.86 %
# [6] train loss: 1.274, validation loss: 1.239, validation acc 55.00 %
# [7] train loss: 1.260, validation loss: 1.251, validation acc 55.18 %
# [8] train loss: 1.221, validation loss: 1.249, validation acc 55.72 %
# ...

# %%
# !python vit.py --pretrained 1 --mode test
# Out:
# Namespace(batch_size=128, dataname='cifar10', drop_rate=0.1, epochs=501, img_size=32, latent_vec_dim=128, lr=0.002, mode='test', num_classes=10, num_heads=8, num_layers=12, patch_size=4, pretrained=1, save_acc=50, weight_decay=0)
# Files already downloaded and verified
# Files already downloaded and verified
# test loss: 0.858, test acc 69.86 %
